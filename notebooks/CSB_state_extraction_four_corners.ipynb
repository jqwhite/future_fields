# %% [markdown]
# # Crop Sequence Boundary data extraction - states

# %% [markdown]
# ## import libraries

# %%
import fiona
import geopandas as gpd
import shapely  # shapely 2.0
import pyogrio
import pyarrow
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from pyproj import CRS
# from mpl_toolkits.basemap import Basemap
from scipy.spatial import KDTree
from shapely.geometry import Point, LineString
import itertools
from operator import itemgetter
from pprint import pprint

# %%
# Set GeoPandas to use pyogrio
gpd.options.io_engine = "pyogrio"

# %%
gpd.show_versions()
# Out:
# SYSTEM INFO
# -----------
# python     : 3.12.4 | packaged by conda-forge | (main, Jun 17 2024, 10:13:44) [Clang 16.0.6 ]
# executable : /Users/jwhite/miniforge3/envs/siads699b/bin/python
# machine    : macOS-14.5-arm64-arm-64bit
#
# GEOS, GDAL, PROJ INFO
# ---------------------
# GEOS       : 3.12.2
# GEOS lib   : None
# GDAL       : 3.9.1
# GDAL data dir: /Users/jwhite/miniforge3/envs/siads699b/share/gdal/
# PROJ       : 9.4.0
# PROJ data dir: /Users/jwhite/miniforge3/envs/siads699b/share/proj
#
# PYTHON DEPENDENCIES
# -------------------
# geopandas  : 1.0.1
# numpy      : 2.0.0
# pandas     : 2.2.2
# pyproj     : 3.6.1
# shapely    : 2.0.5
# pyogrio    : 0.9.0
# geoalchemy2: 0.15.2
# geopy      : 2.4.1
# matplotlib : 3.9.1
# mapclassify: 2.6.1
# fiona      : 1.9.6
# psycopg    : 3.2.1
# psycopg2   : 2.9.9 (dt dec pq3 ext lo64)
# pyarrow    : 16.1.0

# %%
dir(pyogrio)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__gdal_geos_version__',
#  '__gdal_version__',
#  '__gdal_version_string__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_env',
#  '_err',
#  '_geometry',
#  '_io',
#  '_ogr',
#  '_version',
#  '_vsi',
#  'core',
#  'detect_write_driver',
#  'errors',
#  'geopandas',
#  'get_gdal_config_option',
#  'get_gdal_data_path',
#  'list_drivers',
#  'list_layers',
#  'open_arrow',
#  'raw',
#  'read_arrow',
#  'read_bounds',
#  'read_dataframe',
#  'read_info',
#  'set_gdal_config_options',
#  'shapely',
#  'util',
#  'write_arrow',
#  'write_dataframe']

# %% [markdown]
# ## set coordinate reference system for Crop Sequence Bounary
#
# Based on metadata.

# %%
# Set the CRS using PROJ string
# custom coordinate reference system for CropSequenceBoundaries
crs_string = CRS.from_proj4("+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=23 +lon_0=-96 +x_0=0 +y_0=0 +datum=NAD83 +units=m +no_defs +ellps=GRS80")

# %% [markdown]
# ## read latest file and extract data
#
# - Latest data is 2016 to 2023
#
# - Restrict analysis to  Colorado, Utah, Arizona, and New Mexico

# %%
# csb_filepath = '../data/agricultural/CropSequenceBoundaries/NationalCSB_2016-2023_rev23/CSB1623.gdb/'
csb_filepath = '../datasets/fields/NationalCSB_2016-2023_rev23/CSB1623.gdb/'

# %%
layers = fiona.listlayers(csb_filepath)

# %%
len(layers)
# Out:
# 1

# %%
layer = layers[0]
# layer
layer_name = layer
layer_name
# Out:
# 'national1623'

# %%
# Open the geodatabase layer

n = 3 # number of features to collect = n+1

with fiona.open(csb_filepath, layer=layer_name) as src:
    first_n_features = []
    
    # Iterate over the features in the source
    for i, feature in enumerate(src):
        first_n_features.append(feature)
        
        # Break the loop after collecting 10 features
        if i == n:
            break

# %%
first_n_features[:1]
# Out:
# [{'type': 'Feature',
#   'id': '1',
#   'properties': OrderedDict([('CSBID', '351623000000001'),
#                ('CSBYEARS', '1623'),
#                ('CSBACRES', 2.777984416614868),
#                ('CDL2016', 24),
#                ('CDL2017', 24),
#                ('CDL2018', 24),
#                ('CDL2019', 152),
#                ('CDL2020', 152),
#                ('CDL2021', 152),
#                ('CDL2022', 152),
#                ('CDL2023', 152),
#                ('STATEFIPS', '35'),
#                ('STATEASD', '3530'),
#                ('ASD', '30'),
#                ('CNTY', 'Union'),
#                ('CNTYFIPS', '059'),
#                ('INSIDE_X', -650336.707800001),
#                ('INSIDE_Y', 1447440.5062),
#                ('Shape_Length', 628.3153094395814),
#                ('Shape_Area', 11242.14904625621)]),
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[(-650269.8805, 1447270.0971000008),
#       (-650293.9328000005, 1447271.9411999993),
#       (-650317.9850999992, 1447273.7852999996),
#       (-650315.6782000009, 1447303.8725000005),
#       (-650291.6260000002, 1447302.0284000002),
#       (-650286.2434999999, 1447372.2317999993),
#       (-650307.9886000007, 1447404.1631000005),
#       (-650364.1096000001, 1447408.4662999995),
#       (-650361.0335000008, 1447448.5824999996),
#       (-650334.6746999994, 1447476.8254000004),
#       (-650254.5023999996, 1447470.6784000006),
#       (-650269.8805, 1447270.0971000008)]]]}}]

# %% [markdown]
# ## features look like...

# %% [markdown]
# ```
#
# [{'type': 'Feature',
#   'id': '1',
#   'properties': OrderedDict([('CSBID', '351623000000001'),
#                ('CSBYEARS', '1623'),
#                ('CSBACRES', 2.777984416614868),
#                ('CDL2016', 24),
#                ('CDL2017', 24),
#                ('CDL2018', 24),
#                ('CDL2019', 152),
#                ('CDL2020', 152),
#                ('CDL2021', 152),
#                ('CDL2022', 152),
#                ('CDL2023', 152),
#                ('STATEFIPS', '35'),
#                ('STATEASD', '3530'),
#                ('ASD', '30'),
#                ('CNTY', 'Union'),
#                ('CNTYFIPS', '059'),
#                ('INSIDE_X', -650336.707800001),
#                ('INSIDE_Y', 1447440.5062),
#                ('Shape_Length', 628.3153094395814),
#                ('Shape_Area', 11242.14904625621)]),
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[(-650269.8805, 1447270.0971000008),
#       (-650293.9328000005, 1447271.9411999993),
#       (-650317.9850999992, 1447273.7852999996),
#       (-650315.6782000009, 1447303.8725000005),
#       (-650291.6260000002, 1447302.0284000002),
#       (-650286.2434999999, 1447372.2317999993),
#       (-650307.9886000007, 1447404.1631000005),
#       (-650364.1096000001, 1447408.4662999995),
#       (-650361.0335000008, 1447448.5824999996),
#       (-650334.6746999994, 1447476.8254000004),
#       (-650254.5023999996, 1447470.6784000006),
#       (-650269.8805, 1447270.0971000008)]]]}}]
#
#
# ```

# %%
# https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt 
#
# colorado FIPS is 08
# Utah FIPS is 49
# Arizona FIPS is 04
# New Mexico FIPS is 35

statefips = [
    4, # Arizona
    8, # Colorado
    35, # New Mexico
    49, # Arizona
]

# %% [markdown]
# ## test import

# %%
import pandas as pd
import geopandas as gpd
from collections import defaultdict
import pyogrio
from shapely.geometry import shape
from pyproj import CRS

# File paths
# csb_filepath = '../data/agricultural/CropSequenceBoundaries/NationalCSB_2016-2023_rev23/CSB1623.gdb/'
csb_filepath = '../datasets/fields/NationalCSB_2016-2023_rev23/CSB1623.gdb/'
# output_dir = '../data/_generated_data/'
output_dir = '../datasets/fields/csb/'

# Define the STATEFIPS values to filter
statefips = ['4', '8', '35', '49']

# Initialize a dictionary to store the features by CDL2023 codes
cdl2023_features = defaultdict(list)
target_count = 3

# Define the custom CRS using the provided PROJ string
crs_string = "+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=23 +lon_0=-96 +x_0=0 +y_0=0 +datum=NAD83 +units=m +no_defs +ellps=GRS80"
crs = CRS.from_proj4(crs_string)

# Function to read the file in chunks
def read_chunks(filepath, layer, chunk_size=10000):
    start = 0
    while True:
        chunk = pyogrio.read_dataframe(filepath, layer=layer, skip_features=start, max_features=chunk_size)
        if chunk.empty:
            break
        yield chunk
        start += chunk_size

# Read and process the file in chunks
for chunk in read_chunks(csb_filepath, layer=0):
    # Filter the chunk by STATEFIPS
    chunk_filtered = chunk[chunk['STATEFIPS'].isin(statefips)]
    
    # Process each feature in the chunk
    for _, feature in chunk_filtered.iterrows():
        cdl2023 = feature['CDL2023']
        cdl2023_features[cdl2023].append(feature)
        # Stop collecting if we have reached the target count for each CDL2023 code
        if all(len(features) >= target_count for features in cdl2023_features.values()):
            break
    
    # Check if we have reached the target count for each CDL2023 code
    if all(len(features) >= target_count for features in cdl2023_features.values()):
        break

# Select up to 3 features for each unique CDL2023 code
selected_features = []
for cdl2023, features in cdl2023_features.items():
    selected_features.extend(features[:target_count])

# Convert the collected features to a DataFrame and extract geometries
properties_list = [feature.drop(labels='geometry') for feature in selected_features]
geometries = [shape(feature['geometry']) for feature in selected_features]

# Create a GeoDataFrame from the selected features with the custom CRS
gdf_selected = gpd.GeoDataFrame(properties_list, geometry=geometries, crs=crs)

# Rename columns to avoid truncation issues with Shapefile format
gdf_selected = gdf_selected.rename(columns={
    'Shape_Length': 'Shp_Len',
    'Shape_Area': 'Shp_Area',
    # Add other columns if needed
})

# Print the GeoDataFrame
# print(gdf_selected)

# Optionally, save the GeoDataFrame to a file (e.g., shapefile, GeoJSON)
gdf_selected.to_file(f'{output_dir}selected_features.shp')
gdf_selected.to_file(f'{output_dir}selected_features.geojson', driver='GeoJSON')

# %%
# Display the GeoDataFrame in Jupyter Lab
gdf_selected.head()
# gdf_selected
# Out:
#               CSBID CSBYEARS   CSBACRES  CDL2016  CDL2017  CDL2018  CDL2019  \
# 0   351623000000001     1623   2.777984       24       24       24      152
# 5   351623000000006     1623  24.183211       24       24       24      152
# 18  351623000000019     1623   4.837819       24       24       24        4
# 1   351623000000002     1623   9.293348       24       24       24       24
# 2   351623000000003     1623   5.775874       24       24       24       24
#
#     CDL2020  CDL2021  CDL2022  ...  STATEFIPS STATEASD ASD     CNTY CNTYFIPS  \
# 0       152      152      152  ...         35     3530  30    Union      059
# 5       152      152      152  ...         35     3530  30    Union      059
# 18        4       61       61  ...         35     3530  30  Harding      021
# 1        24       24       24  ...         35     3530  30    Union      059
# 2        24       24       24  ...         35     3530  30    Union      059
#
#        INSIDE_X      INSIDE_Y      Shp_Len      Shp_Area  \
# 0  -650336.7078  1.447441e+06   628.315309  11242.149046
# 5  -650353.4439  1.447107e+06  1761.059250  97866.372287
# 18 -663657.5201  1.445929e+06   630.227129  19578.037389
# 1  -648203.5992  1.447142e+06  1042.818836  37608.996229
# 2  -647571.4914  1.447064e+06  1164.537470  23374.226788
#
#                                              geometry
# 0   MULTIPOLYGON (((-650269.880 1447270.097, -6502...
# 5   MULTIPOLYGON (((-650317.985 1447273.785, -6503...
# 18  MULTIPOLYGON (((-663619.003 1446023.964, -6636...
# 1   MULTIPOLYGON (((-648233.790 1447215.119, -6481...
# 2   MULTIPOLYGON (((-647690.945 1446931.542, -6476...
#
# [5 rows x 21 columns]

# %%
gdf_selected.columns
# Out:
# Index(['CSBID', 'CSBYEARS', 'CSBACRES', 'CDL2016', 'CDL2017', 'CDL2018',
#        'CDL2019', 'CDL2020', 'CDL2021', 'CDL2022', 'CDL2023', 'STATEFIPS',
#        'STATEASD', 'ASD', 'CNTY', 'CNTYFIPS', 'INSIDE_X', 'INSIDE_Y',
#        'Shp_Len', 'Shp_Area', 'geometry'],
#       dtype='object')

# %% [markdown]
# ## Extract CSBs for Arizona, New Mexico, Utah, and Colorado
#
# FIPS codes are here:
# https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt

# %% [markdown]
# ### test extractions

# %% [markdown]
# ### extraction all four states

# %%
import pandas as pd
import geopandas as gpd
import pyogrio
from shapely.geometry import shape
from pyproj import CRS
import time

# File paths
csb_filepath = '../datasets/fields/NationalCSB_2016-2023_rev23/CSB1623.gdb/'
output_dir = '../datasets/fields/csb/'

# Define the custom CRS using the provided PROJ string
crs_string = "+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=23 +lon_0=-96 +x_0=0 +y_0=0 +datum=NAD83 +units=m +no_defs +ellps=GRS80"
custom_crs = CRS.from_proj4(crs_string)

# Define the STATEFIPS value to filter
statefips = '35'  # New Mexico
# statefips = '04' # Arizona

# Initialize a list to store the features
selected_features = []

# Function to read the file in chunks
def read_chunks(filepath, layer, chunk_size=1000):
    start = 0
    while True:
        chunk = pyogrio.read_dataframe(filepath, layer=layer, skip_features=start, max_features=chunk_size)
        if chunk.empty:
            break
        yield chunk
        start += chunk_size

# Timing the execution
start_time = time.time()
chunk_index = 0

# Get the total number of features in the dataset and print the information for debugging
info = pyogrio.read_info(csb_filepath, layer=0)
print(f"Dataset info:")
pprint(info)

# Use the appropriate key to get the total number of features
total_features = info.get('features') or info.get('feature_count')
if total_features is None:
    raise KeyError("Unable to determine the total number of features in the dataset")

print()
print(f"Total number of features in the dataset: {total_features}")

# Set a limit on the number of chunks to process for testing
max_chunks = 5  # Limit the number of chunks for testing

# Read and process the file in chunks
for chunk in read_chunks(csb_filepath, layer=0, chunk_size=1000):
    chunk_start_time = time.time()
    chunk_index += 1

    # Filter the chunk by STATEFIPS
    chunk_filtered = chunk[chunk['STATEFIPS'] == statefips]

    # Collect the filtered features
    selected_features.extend(chunk_filtered.to_dict('records'))

    chunk_end_time = time.time()
    print(f"Processed chunk {chunk_index:>6} in {chunk_end_time - chunk_start_time:.2f} seconds, total features collected: {len(selected_features):>8}")

    # Break the loop if the maximum number of chunks for testing is reached
    if chunk_index >= max_chunks:
        break

    # Break the loop if we have read all features
    if chunk_index * 1000 >= total_features:
        break

# Convert the collected features to a DataFrame and extract geometries
properties_list = [pd.Series(feature).drop(labels='geometry') for feature in selected_features]
geometries = [shape(feature['geometry']) for feature in selected_features]

# Create a GeoDataFrame from the selected features using the custom CRS
gdf_selected = gpd.GeoDataFrame(properties_list, geometry=geometries, crs=custom_crs)

# Rename columns to avoid truncation issues with Shapefile format
gdf_selected = gdf_selected.rename(columns={
    'Shape_Length': 'Shp_Len',
    'Shape_Area': 'Shp_Area',
    # Add other columns if needed
})

# # Save the GeoDataFrame to a file (e.g., shapefile, GeoJSON, Parquet)
# gdf_selected.to_file(f'{output_dir}selected_features_fips_35.shp')
# gdf_selected.to_file(f'{output_dir}selected_features_fips_35.geojson', driver='GeoJSON')
# gdf_selected.to_parquet(f'{output_dir}selected_features_fips_35.parquet')

# Print the execution time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Script execution time: {elapsed_time:.2f} seconds")
# Out:
# Dataset info:
# {'capabilities': {'fast_set_next_by_index': 1,
#                   'fast_spatial_filter': 1,
#                   'random_read': 1},
#  'crs': 'PROJCS["Albers_Conic_Equal_Area",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS '
#         '1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]',
#  'dtypes': array(['object', 'object', 'float64', 'int32', 'int32', 'int32', 'int32',
#        'int32', 'int32', 'int32', 'int32', 'object', 'object', 'object',
#        'object', 'object', 'float64', 'float64', 'float64', 'float64'],
#       dtype=object),
#  'encoding': 'UTF-8',
#  'features': 16194800,
#  'fields': array(['CSBID', 'CSBYEARS', 'CSBACRES', 'CDL2016', 'CDL2017', 'CDL2018',
#        'CDL2019', 'CDL2020', 'CDL2021', 'CDL2022', 'CDL2023', 'STATEFIPS',
#        'STATEASD', 'ASD', 'CNTY', 'CNTYFIPS', 'INSIDE_X', 'INSIDE_Y',
#        'Shape_Length', 'Shape_Area'], dtype=object),
#  'geometry_type': 'MultiPolygon'}
#
# Total number of features in the dataset: 16194800
# Processed chunk      1 in 0.01 seconds, total features collected:      708
# Processed chunk      2 in 0.00 seconds, total features collected:      708
# Processed chunk      3 in 0.00 seconds, total features collected:      708
# Processed chunk      4 in 0.01 seconds, total features collected:     1607
# Processed chunk      5 in 0.00 seconds, total features collected:     1746
# Script execution time: 0.91 seconds

# %%
import pandas as pd
import geopandas as gpd
import pyogrio
from shapely.geometry import shape
from pyproj import CRS
import time
from pprint import pprint
import psutil
import os
from datetime import datetime

# File paths
csb_filepath = '../datasets/fields/NationalCSB_2016-2023_rev23/CSB1623.gdb/'
output_dir = '../datasets/fields/csb/'

# Define the custom CRS using the provided PROJ string
crs_string = "+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=23 +lon_0=-96 +x_0=0 +y_0=0 +datum=NAD83 +units=m +no_defs +ellps=GRS80"
custom_crs = CRS.from_proj4(crs_string)

# Define the STATEFIPS values to filter
statefips = ['04', '08', '35', '49']  # Arizona, Colorado, New Mexico, Utah
# statefips = ['04', '08']  # Arizona, Colorado - to check FIPS

# Initialize a dictionary to store the features by state
state_features = {fips: [] for fips in statefips}

# Function to read the file in chunks, starting at a specific chunk
def read_chunks(filepath, layer, chunk_size, total_features, start_chunk=0):
    start = start_chunk * chunk_size
    while start < total_features:
        remaining_features = total_features - start
        if remaining_features < chunk_size:
            chunk_size = remaining_features
        chunk = pyogrio.read_dataframe(filepath, layer=layer, skip_features=start, max_features=chunk_size)
        if chunk.empty:
            break
        yield chunk
        start += chunk_size

# Function to monitor memory usage
def print_memory_usage():
    process = psutil.Process()
    memory_info = process.memory_info()
    print(f"Memory usage: {memory_info.rss / 1024**2:.2f} MB")

# Timing the execution
start_time = time.time()

# Get the total number of features in the dataset
info = pyogrio.read_info(csb_filepath, layer=0)

# Print the dataset info in a nicely formatted way
print("Dataset info:")
pprint(info)

total_features = info.get('features') or info.get('feature_count')
if total_features is None:
    raise KeyError("Unable to determine the total number of features in the dataset")

print(f"Total number of features in the dataset: {total_features}")

# Set chunk size
chunk_size = 1000

# Set the starting chunk index
# start_chunk = 15092
start_chunk=0
chunk_index = start_chunk

# Read and process the file in chunks
for chunk in read_chunks(csb_filepath, layer=0, chunk_size=chunk_size, total_features=total_features, start_chunk=start_chunk):
    chunk_start_time = time.time()
    chunk_index += 1

    # Filter the chunk by STATEFIPS
    chunk_filtered = chunk[chunk['STATEFIPS'].isin(statefips)]

    # Collect the filtered features by state
    for state_fips in statefips:
        state_features[state_fips].extend(chunk_filtered[chunk_filtered['STATEFIPS'] == state_fips].to_dict('records'))

    chunk_end_time = time.time()
    print(f"Processed chunk {chunk_index:>6}, total features collected: {sum(len(features) for features in state_features.values()):>8}")

    # Print memory usage
    print_memory_usage()

# Get the current timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Convert the collected features to a DataFrame and extract geometries
for state_fips, features in state_features.items():
    properties_list = [pd.Series(feature).drop(labels='geometry') for feature in features]
    geometries = [shape(feature['geometry']) for feature in features]

    # Create a GeoDataFrame from the selected features using the custom CRS
    gdf_selected = gpd.GeoDataFrame(properties_list, geometry=geometries, crs=custom_crs)

    # Rename columns to avoid truncation issues with Shapefile format
    gdf_selected = gdf_selected.rename(columns={
        'Shape_Length': 'Shp_Len',
        'Shape_Area': 'Shp_Area',
        # Add other columns if needed
    })

    # Create a subfolder for .shp files for each state
    shapefile_dir = os.path.join(output_dir, f'{timestamp}_selected_features_fips_{state_fips}_shape/')
    os.makedirs(shapefile_dir, exist_ok=True)

    # Save the GeoDataFrame to a file (e.g., shapefile, GeoJSON, Parquet) with a timestamp
    gdf_selected.to_file(f'{shapefile_dir}selected_features_fips_{state_fips}.shp')
    gdf_selected.to_file(f'{output_dir}{timestamp}_selected_features_fips_{state_fips}.geojson', driver='GeoJSON')
    gdf_selected.to_parquet(f'{output_dir}{timestamp}_selected_features_fips_{state_fips}.parquet')

# Print the execution time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Script execution time: {elapsed_time:.2f} seconds")
# Out:
# Dataset info:
# {'capabilities': {'fast_set_next_by_index': 1,
#                   'fast_spatial_filter': 1,
#                   'random_read': 1},
#  'crs': 'PROJCS["Albers_Conic_Equal_Area",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS '
#         '1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]',
#  'dtypes': array(['object', 'object', 'float64', 'int32', 'int32', 'int32', 'int32',
#        'int32', 'int32', 'int32', 'int32', 'object', 'object', 'object',
#        'object', 'object', 'float64', 'float64', 'float64', 'float64'],
#       dtype=object),
#  'encoding': 'UTF-8',
#  'features': 16194800,
#  'fields': array(['CSBID', 'CSBYEARS', 'CSBACRES', 'CDL2016', 'CDL2017', 'CDL2018',
#        'CDL2019', 'CDL2020', 'CDL2021', 'CDL2022', 'CDL2023', 'STATEFIPS',
#        'STATEASD', 'ASD', 'CNTY', 'CNTYFIPS', 'INSIDE_X', 'INSIDE_Y',
#        'Shape_Length', 'Shape_Area'], dtype=object),
#  'geometry_type': 'MultiPolygon'}
# Total number of features in the dataset: 16194800
# Processed chunk      1, total features collected:      708
# Memory usage: 232.84 MB
# Processed chunk      2, total features collected:      708
# Memory usage: 239.58 MB
# Processed chunk      3, total features collected:      708
# Memory usage: 242.72 MB
# Processed chunk      4, total features collected:     1607
# Memory usage: 245.66 MB
# Processed chunk      5, total features collected:     1746
# Memory usage: 247.88 MB
# Processed chunk      6, total features collected:     1746
# Memory usage: 252.86 MB
# Processed chunk      7, total features collected:     1746
# Memory usage: 255.67 MB
# Processed chunk      8, total features collected:     1945
# Memory usage: 258.94 MB
# Processed chunk      9, total features collected:     2454
# Memory usage: 260.27 MB
# Processed chunk     10, total features collected:     3139
# Memory usage: 262.39 MB
# Processed chunk     11, total features collected:     3139
# Memory usage: 264.80 MB
# Processed chunk     12, total features collected:     3139
# Memory usage: 266.66 MB
# Processed chunk     13, total features collected:     3139
# Memory usage: 268.11 MB
# Processed chunk     14, total features collected:     3139
# Memory usage: 269.80 MB
# Processed chunk     15, total features collected:     3139
# Memory usage: 272.97 MB
# Processed chunk     16, total features collected:     3139
# Memory usage: 274.06 MB
# Processed chunk     17, total features collected:     3139
# Memory usage: 275.33 MB
# Processed chunk     18, total features collected:     3139
# Memory usage: 277.02 MB
# Processed chunk     19, total features collected:     3139
# Memory usage: 278.45 MB
# Processed chunk     20, total features collected:     3139
# Memory usage: 281.53 MB
# Processed chunk     21, total features collected:     3139
# Memory usage: 282.62 MB
# Processed chunk     22, total features collected:     3139
# Memory usage: 285.14 MB
# Processed chunk     23, total features collected:     3139
# Memory usage: 286.05 MB
# Processed chunk     24, total features collected:     3139
# Memory usage: 286.91 MB
# Processed chunk     25, total features collected:     3139
# Memory usage: 288.39 MB
# Processed chunk     26, total features collected:     3139
# Memory usage: 289.00 MB
# Processed chunk     27, total features collected:     3139
# Memory usage: 290.75 MB
# Processed chunk     28, total features collected:     3139
# Memory usage: 293.19 MB
# Processed chunk     29, total features collected:     3139
# Memory usage: 295.92 MB
# Processed chunk     30, total features collected:     3139
# Memory usage: 297.42 MB
# Processed chunk     31, total features collected:     3139
# Memory usage: 298.89 MB
# Processed chunk     32, total features collected:     3139
# Memory usage: 300.23 MB
# Processed chunk     33, total features collected:     3139
# Memory usage: 301.48 MB
# Processed chunk     34, total features collected:     3139
# Memory usage: 303.69 MB
# Processed chunk     35, total features collected:     3139
# Memory usage: 306.03 MB
# Processed chunk     36, total features collected:     3139
# Memory usage: 309.41 MB
# Processed chunk     37, total features collected:     3139
# Memory usage: 310.69 MB
# Processed chunk     38, total features collected:     3139
# Memory usage: 313.22 MB
# Processed chunk     39, total features collected:     3139
# Memory usage: 318.34 MB
# Processed chunk     40, total features collected:     3139
# Memory usage: 322.56 MB
# Processed chunk     41, total features collected:     3139
# Memory usage: 324.56 MB
# Processed chunk     42, total features collected:     3139
# Memory usage: 327.55 MB
# Processed chunk     43, total features collected:     3139
# Memory usage: 328.64 MB
# Processed chunk     44, total features collected:     3139
# Memory usage: 331.12 MB
# Processed chunk     45, total features collected:     3139
# Memory usage: 334.83 MB
# Processed chunk     46, total features collected:     3272
# Memory usage: 336.06 MB
# Processed chunk     47, total features collected:     3865
# Memory usage: 337.80 MB
# Processed chunk     48, total features collected:     3865
# Memory usage: 340.36 MB
# Processed chunk     49, total features collected:     3865
# Memory usage: 343.78 MB
# Processed chunk     50, total features collected:     3865
# Memory usage: 346.14 MB
# Processed chunk     51, total features collected:     3865
# Memory usage: 349.39 MB
# Processed chunk     52, total features collected:     3865
# Memory usage: 350.81 MB
# Processed chunk     53, total features collected:     3865
# Memory usage: 352.38 MB
# Processed chunk     54, total features collected:     3865
# Memory usage: 353.95 MB
# Processed chunk     55, total features collected:     4237
# Memory usage: 357.00 MB
# Processed chunk     56, total features collected:     4237
# Memory usage: 360.14 MB
# Processed chunk     57, total features collected:     4237
# Memory usage: 362.92 MB
# Processed chunk     58, total features collected:     4237
# Memory usage: 366.09 MB
# Processed chunk     59, total features collected:     4237
# Memory usage: 370.09 MB
# Processed chunk     60, total features collected:     5136
# Memory usage: 373.91 MB
# Processed chunk     61, total features collected:     6136
# Memory usage: 374.62 MB
# Processed chunk     62, total features collected:     7136
# Memory usage: 377.83 MB
# Processed chunk     63, total features collected:     8136
# Memory usage: 379.34 MB
# Processed chunk     64, total features collected:     9136
# Memory usage: 381.67 MB
# Processed chunk     65, total features collected:    10136
# Memory usage: 384.31 MB
# Processed chunk     66, total features collected:    11136
# Memory usage: 387.67 MB
# Processed chunk     67, total features collected:    12056
# Memory usage: 393.23 MB
# Processed chunk     68, total features collected:    12056
# Memory usage: 395.50 MB
# Processed chunk     69, total features collected:    12056
# Memory usage: 398.56 MB
# Processed chunk     70, total features collected:    12056
# Memory usage: 402.00 MB
# Processed chunk     71, total features collected:    12056
# Memory usage: 404.17 MB
# Processed chunk     72, total features collected:    12056
# Memory usage: 406.66 MB
# Processed chunk     73, total features collected:    12659
# Memory usage: 408.59 MB
# Processed chunk     74, total features collected:    12659
# Memory usage: 410.70 MB
# Processed chunk     75, total features collected:    12659
# Memory usage: 413.84 MB
# Processed chunk     76, total features collected:    12659
# Memory usage: 418.11 MB
# Processed chunk     77, total features collected:    12659
# Memory usage: 419.42 MB
# Processed chunk     78, total features collected:    12659
# Memory usage: 420.36 MB
# Processed chunk     79, total features collected:    12659
# Memory usage: 421.38 MB
# Processed chunk     80, total features collected:    12659
# Memory usage: 422.22 MB
# Processed chunk     81, total features collected:    12659
# Memory usage: 423.91 MB
# Processed chunk     82, total features collected:    12659
# Memory usage: 425.14 MB
# Processed chunk     83, total features collected:    12659
# Memory usage: 426.28 MB
# Processed chunk     84, total features collected:    12659
# Memory usage: 427.41 MB
# Processed chunk     85, total features collected:    12659
# Memory usage: 429.09 MB
# Processed chunk     86, total features collected:    12659
# Memory usage: 431.38 MB
# Processed chunk     87, total features collected:    12659
# Memory usage: 432.62 MB
# Processed chunk     88, total features collected:    12659
# Memory usage: 433.41 MB
# Processed chunk     89, total features collected:    12659
# Memory usage: 433.91 MB
# Processed chunk     90, total features collected:    12659
# Memory usage: 434.97 MB
# Processed chunk     91, total features collected:    12659
# Memory usage: 435.72 MB
# Processed chunk     92, total features collected:    12659
# Memory usage: 436.27 MB
# Processed chunk     93, total features collected:    12659
# Memory usage: 438.20 MB
# Processed chunk     94, total features collected:    12659
# Memory usage: 439.72 MB
# Processed chunk     95, total features collected:    12659
# Memory usage: 441.17 MB
# Processed chunk     96, total features collected:    12659
# Memory usage: 442.12 MB
# Processed chunk     97, total features collected:    12659
# Memory usage: 443.52 MB
# Processed chunk     98, total features collected:    12659
# Memory usage: 445.75 MB
# Processed chunk     99, total features collected:    12659
# Memory usage: 446.70 MB
# Processed chunk    100, total features collected:    12659
# Memory usage: 447.58 MB
# Processed chunk    101, total features collected:    12659
# Memory usage: 448.55 MB
# Processed chunk    102, total features collected:    12659
# Memory usage: 449.72 MB
# Processed chunk    103, total features collected:    12659
# Memory usage: 452.31 MB
# Processed chunk    104, total features collected:    12659
# Memory usage: 456.92 MB
# Processed chunk    105, total features collected:    12659
# Memory usage: 460.12 MB
# Processed chunk    106, total features collected:    12659
# Memory usage: 462.02 MB
# Processed chunk    107, total features collected:    12659
# Memory usage: 463.16 MB
# Processed chunk    108, total features collected:    12659
# Memory usage: 467.27 MB
# Processed chunk    109, total features collected:    12659
# Memory usage: 468.23 MB
# Processed chunk    110, total features collected:    12659
# Memory usage: 469.36 MB
# Processed chunk    111, total features collected:    12659
# Memory usage: 470.64 MB
# Processed chunk    112, total features collected:    12659
# Memory usage: 471.30 MB
# Processed chunk    113, total features collected:    12659
# Memory usage: 472.38 MB
# Processed chunk    114, total features collected:    12659
# Memory usage: 473.78 MB
# Processed chunk    115, total features collected:    12659
# Memory usage: 474.70 MB
# Processed chunk    116, total features collected:    12659
# Memory usage: 475.98 MB
# Processed chunk    117, total features collected:    12659
# Memory usage: 477.08 MB
# Processed chunk    118, total features collected:    12659
# Memory usage: 479.45 MB
# Processed chunk    119, total features collected:    12659
# Memory usage: 480.98 MB
# Processed chunk    120, total features collected:    12659
# Memory usage: 483.69 MB
# Processed chunk    121, total features collected:    12659
# Memory usage: 484.27 MB
# Processed chunk    122, total features collected:    12659
# Memory usage: 487.56 MB
# Processed chunk    123, total features collected:    12659
# Memory usage: 489.56 MB
# Processed chunk    124, total features collected:    12659
# Memory usage: 493.19 MB
# Processed chunk    125, total features collected:    12659
# Memory usage: 493.72 MB
# Processed chunk    126, total features collected:    12659
# Memory usage: 495.11 MB
# Processed chunk    127, total features collected:    12659
# Memory usage: 497.05 MB
# Processed chunk    128, total features collected:    12659
# Memory usage: 498.09 MB
# Processed chunk    129, total features collected:    12659
# Memory usage: 499.06 MB
# Processed chunk    130, total features collected:    12659
# Memory usage: 500.31 MB
# Processed chunk    131, total features collected:    12659
# Memory usage: 502.25 MB
# Processed chunk    132, total features collected:    12659
# Memory usage: 503.33 MB
# Processed chunk    133, total features collected:    12659
# Memory usage: 504.02 MB
# Processed chunk    134, total features collected:    12659
# Memory usage: 505.23 MB
# Processed chunk    135, total features collected:    12659
# Memory usage: 507.50 MB
# Processed chunk    136, total features collected:    12659
# Memory usage: 511.05 MB
# Processed chunk    137, total features collected:    12659
# Memory usage: 511.75 MB
# Processed chunk    138, total features collected:    12659
# Memory usage: 515.12 MB
# Processed chunk    139, total features collected:    12659
# Memory usage: 516.83 MB
# Processed chunk    140, total features collected:    12659
# Memory usage: 518.59 MB
# Processed chunk    141, total features collected:    12659
# Memory usage: 519.33 MB
# Processed chunk    142, total features collected:    12659
# Memory usage: 521.58 MB
# Processed chunk    143, total features collected:    12659
# Memory usage: 525.19 MB
# Processed chunk    144, total features collected:    12659
# Memory usage: 526.17 MB
# Processed chunk    145, total features collected:    12659
# Memory usage: 527.08 MB
# Processed chunk    146, total features collected:    13142
# Memory usage: 529.00 MB
# Processed chunk    147, total features collected:    13142
# Memory usage: 530.17 MB
# Processed chunk    148, total features collected:    13695
# Memory usage: 531.50 MB
# Processed chunk    149, total features collected:    14505
# Memory usage: 533.88 MB
# Processed chunk    150, total features collected:    14505
# Memory usage: 536.14 MB
# Processed chunk    151, total features collected:    14505
# Memory usage: 539.77 MB
# Processed chunk    152, total features collected:    14505
# Memory usage: 541.38 MB
# Processed chunk    153, total features collected:    14505
# Memory usage: 543.27 MB
# Processed chunk    154, total features collected:    14505
# Memory usage: 544.17 MB
# Processed chunk    155, total features collected:    14505
# Memory usage: 544.58 MB
# Processed chunk    156, total features collected:    14505
# Memory usage: 547.92 MB
# Processed chunk    157, total features collected:    14505
# Memory usage: 550.08 MB
# Processed chunk    158, total features collected:    14505
# Memory usage: 554.33 MB
# Processed chunk    159, total features collected:    14505
# Memory usage: 557.58 MB
# Processed chunk    160, total features collected:    14505
# Memory usage: 558.25 MB
# Processed chunk    161, total features collected:    14505
# Memory usage: 559.77 MB
# Processed chunk    162, total features collected:    14505
# Memory usage: 560.84 MB
# Processed chunk    163, total features collected:    14505
# Memory usage: 561.81 MB
# Processed chunk    164, total features collected:    14505
# Memory usage: 562.88 MB
# Processed chunk    165, total features collected:    14505
# Memory usage: 564.89 MB
# Processed chunk    166, total features collected:    14505
# Memory usage: 565.92 MB
# Processed chunk    167, total features collected:    14505
# Memory usage: 568.78 MB
# Processed chunk    168, total features collected:    14505
# Memory usage: 571.22 MB
# Processed chunk    169, total features collected:    14505
# Memory usage: 574.77 MB
# Processed chunk    170, total features collected:    14697
# Memory usage: 577.12 MB
# Processed chunk    171, total features collected:    15297
# Memory usage: 580.97 MB
# Processed chunk    172, total features collected:    15297
# Memory usage: 585.08 MB
# Processed chunk    173, total features collected:    15297
# Memory usage: 588.16 MB
# Processed chunk    174, total features collected:    15297
# Memory usage: 592.28 MB
# Processed chunk    175, total features collected:    15297
# Memory usage: 595.70 MB
# Processed chunk    176, total features collected:    15297
# Memory usage: 597.28 MB
# Processed chunk    177, total features collected:    15297
# Memory usage: 598.89 MB
# Processed chunk    178, total features collected:    15297
# Memory usage: 600.72 MB
# Processed chunk    179, total features collected:    15297
# Memory usage: 601.56 MB
# Processed chunk    180, total features collected:    15297
# Memory usage: 604.16 MB
# Processed chunk    181, total features collected:    15297
# Memory usage: 607.97 MB
# Processed chunk    182, total features collected:    15297
# Memory usage: 611.28 MB
# Processed chunk    183, total features collected:    15297
# Memory usage: 612.77 MB
# Processed chunk    184, total features collected:    15297
# Memory usage: 615.69 MB
# Processed chunk    185, total features collected:    15297
# Memory usage: 617.06 MB
# Processed chunk    186, total features collected:    15297
# Memory usage: 619.39 MB
# Processed chunk    187, total features collected:    15297
# Memory usage: 623.14 MB
# Processed chunk    188, total features collected:    15297
# Memory usage: 624.69 MB
# Processed chunk    189, total features collected:    15297
# Memory usage: 625.17 MB
# Processed chunk    190, total features collected:    15297
# Memory usage: 626.66 MB
# Processed chunk    191, total features collected:    15297
# Memory usage: 627.75 MB
# Processed chunk    192, total features collected:    15297
# Memory usage: 629.03 MB
# Processed chunk    193, total features collected:    15297
# Memory usage: 630.98 MB
# Processed chunk    194, total features collected:    15297
# Memory usage: 631.98 MB
# Processed chunk    195, total features collected:    15297
# Memory usage: 634.56 MB
# Processed chunk    196, total features collected:    15297
# Memory usage: 635.36 MB
# Processed chunk    197, total features collected:    15297
# Memory usage: 636.30 MB
# Processed chunk    198, total features collected:    15297
# Memory usage: 637.22 MB
# Processed chunk    199, total features collected:    15297
# Memory usage: 638.52 MB
# Processed chunk    200, total features collected:    15297
# Memory usage: 638.95 MB
# Processed chunk    201, total features collected:    15297
# Memory usage: 640.44 MB
# Processed chunk    202, total features collected:    15297
# Memory usage: 642.14 MB
# Processed chunk    203, total features collected:    15297
# Memory usage: 643.94 MB
# Processed chunk    204, total features collected:    15297
# Memory usage: 645.33 MB
# Processed chunk    205, total features collected:    15297
# Memory usage: 646.27 MB
# Processed chunk    206, total features collected:    15297
# Memory usage: 649.44 MB
# Processed chunk    207, total features collected:    15297
# Memory usage: 650.78 MB
# Processed chunk    208, total features collected:    15297
# Memory usage: 652.48 MB
# Processed chunk    209, total features collected:    15297
# Memory usage: 653.05 MB
# Processed chunk    210, total features collected:    15297
# Memory usage: 653.95 MB
# Processed chunk    211, total features collected:    15297
# Memory usage: 654.86 MB
# Processed chunk    212, total features collected:    15297
# Memory usage: 655.83 MB
# Processed chunk    213, total features collected:    15297
# Memory usage: 656.81 MB
# Processed chunk    214, total features collected:    15297
# Memory usage: 658.56 MB
# Processed chunk    215, total features collected:    15297
# Memory usage: 659.33 MB
# Processed chunk    216, total features collected:    16038
# Memory usage: 660.45 MB
# Processed chunk    217, total features collected:    16126
# Memory usage: 663.22 MB
# Processed chunk    218, total features collected:    16126
# Memory usage: 665.27 MB
# Processed chunk    219, total features collected:    16126
# Memory usage: 666.92 MB
# Processed chunk    220, total features collected:    16126
# Memory usage: 667.92 MB
# Processed chunk    221, total features collected:    16126
# Memory usage: 669.61 MB
# Processed chunk    222, total features collected:    16126
# Memory usage: 670.08 MB
# Processed chunk    223, total features collected:    16126
# Memory usage: 671.34 MB
# Processed chunk    224, total features collected:    16939
# Memory usage: 674.31 MB
# Processed chunk    225, total features collected:    17939
# Memory usage: 676.23 MB
# Processed chunk    226, total features collected:    18696
# Memory usage: 678.89 MB
# Processed chunk    227, total features collected:    18696
# Memory usage: 681.41 MB
# Processed chunk    228, total features collected:    18696
# Memory usage: 683.88 MB
# Processed chunk    229, total features collected:    18696
# Memory usage: 684.70 MB
# Processed chunk    230, total features collected:    18696
# Memory usage: 686.81 MB
# Processed chunk    231, total features collected:    18696
# Memory usage: 690.97 MB
# Processed chunk    232, total features collected:    18696
# Memory usage: 694.50 MB
# Processed chunk    233, total features collected:    18696
# Memory usage: 696.69 MB
# Processed chunk    234, total features collected:    18696
# Memory usage: 697.70 MB
# Processed chunk    235, total features collected:    19470
# Memory usage: 698.42 MB
# Processed chunk    236, total features collected:    19604
# Memory usage: 700.47 MB
# Processed chunk    237, total features collected:    19604
# Memory usage: 703.23 MB
# Processed chunk    238, total features collected:    19604
# Memory usage: 704.33 MB
# Processed chunk    239, total features collected:    19604
# Memory usage: 705.45 MB
# Processed chunk    240, total features collected:    19604
# Memory usage: 706.75 MB
# Processed chunk    241, total features collected:    19604
# Memory usage: 709.55 MB
# Processed chunk    242, total features collected:    19604
# Memory usage: 710.30 MB
# Processed chunk    243, total features collected:    19604
# Memory usage: 710.92 MB
# Processed chunk    244, total features collected:    19604
# Memory usage: 712.25 MB
# Processed chunk    245, total features collected:    19604
# Memory usage: 714.16 MB
# Processed chunk    246, total features collected:    19604
# Memory usage: 715.39 MB
# Processed chunk    247, total features collected:    19604
# Memory usage: 716.05 MB
# Processed chunk    248, total features collected:    19604
# Memory usage: 716.89 MB
# Processed chunk    249, total features collected:    19604
# Memory usage: 719.02 MB
# Processed chunk    250, total features collected:    19604
# Memory usage: 720.31 MB
# Processed chunk    251, total features collected:    19604
# Memory usage: 721.44 MB
# Processed chunk    252, total features collected:    19604
# Memory usage: 722.28 MB
# Processed chunk    253, total features collected:    19604
# Memory usage: 723.34 MB
# Processed chunk    254, total features collected:    19604
# Memory usage: 724.62 MB
# Processed chunk    255, total features collected:    19604
# Memory usage: 726.02 MB
# Processed chunk    256, total features collected:    19604
# Memory usage: 728.08 MB
# Processed chunk    257, total features collected:    19604
# Memory usage: 729.77 MB
# Processed chunk    258, total features collected:    19604
# Memory usage: 731.64 MB
# Processed chunk    259, total features collected:    19604
# Memory usage: 732.81 MB
# Processed chunk    260, total features collected:    19604
# Memory usage: 733.50 MB
# Processed chunk    261, total features collected:    19604
# Memory usage: 734.22 MB
# Processed chunk    262, total features collected:    19604
# Memory usage: 735.62 MB
# Processed chunk    263, total features collected:    19604
# Memory usage: 736.80 MB
# Processed chunk    264, total features collected:    19604
# Memory usage: 738.16 MB
# Processed chunk    265, total features collected:    19604
# Memory usage: 739.78 MB
# Processed chunk    266, total features collected:    19604
# Memory usage: 740.94 MB
# Processed chunk    267, total features collected:    19604
# Memory usage: 741.61 MB
# Processed chunk    268, total features collected:    19604
# Memory usage: 742.38 MB
# Processed chunk    269, total features collected:    19604
# Memory usage: 743.34 MB
# Processed chunk    270, total features collected:    19604
# Memory usage: 744.86 MB
# Processed chunk    271, total features collected:    19604
# Memory usage: 745.67 MB
# Processed chunk    272, total features collected:    19604
# Memory usage: 746.73 MB
# Processed chunk    273, total features collected:    19604
# Memory usage: 747.86 MB
# Processed chunk    274, total features collected:    19604
# Memory usage: 749.64 MB
# Processed chunk    275, total features collected:    19604
# Memory usage: 750.48 MB
# Processed chunk    276, total features collected:    19604
# Memory usage: 751.12 MB
# Processed chunk    277, total features collected:    19604
# Memory usage: 752.25 MB
# Processed chunk    278, total features collected:    19604
# Memory usage: 754.44 MB
# Processed chunk    279, total features collected:    19604
# Memory usage: 755.02 MB
# Processed chunk    280, total features collected:    19604
# Memory usage: 755.72 MB
# Processed chunk    281, total features collected:    20344
# Memory usage: 757.08 MB
# Processed chunk    282, total features collected:    20920
# Memory usage: 758.61 MB
# Processed chunk    283, total features collected:    20920
# Memory usage: 760.31 MB
# Processed chunk    284, total features collected:    20920
# Memory usage: 762.22 MB
# Processed chunk    285, total features collected:    20920
# Memory usage: 763.36 MB
# Processed chunk    286, total features collected:    20920
# Memory usage: 764.80 MB
# Processed chunk    287, total features collected:    20920
# Memory usage: 766.50 MB
# Processed chunk    288, total features collected:    20920
# Memory usage: 742.11 MB
# Processed chunk    289, total features collected:    20920
# Memory usage: 744.89 MB
# Processed chunk    290, total features collected:    20920
# Memory usage: 747.36 MB
# Processed chunk    291, total features collected:    20920
# Memory usage: 750.11 MB
# Processed chunk    292, total features collected:    20920
# Memory usage: 752.88 MB
# Processed chunk    293, total features collected:    20920
# Memory usage: 754.80 MB
# Processed chunk    294, total features collected:    20920
# Memory usage: 755.83 MB
# Processed chunk    295, total features collected:    20920
# Memory usage: 757.11 MB
# Processed chunk    296, total features collected:    20920
# Memory usage: 759.95 MB
# Processed chunk    297, total features collected:    20920
# Memory usage: 762.14 MB
# Processed chunk    298, total features collected:    20920
# Memory usage: 762.89 MB
# Processed chunk    299, total features collected:    20920
# Memory usage: 764.14 MB
# Processed chunk    300, total features collected:    20920
# Memory usage: 758.95 MB
# Processed chunk    301, total features collected:    20920
# Memory usage: 760.30 MB
# Processed chunk    302, total features collected:    20920
# Memory usage: 761.53 MB
# Processed chunk    303, total features collected:    20920
# Memory usage: 761.89 MB
# Processed chunk    304, total features collected:    20920
# Memory usage: 714.42 MB
# Processed chunk    305, total features collected:    20920
# Memory usage: 715.45 MB
# Processed chunk    306, total features collected:    20920
# Memory usage: 717.33 MB
# Processed chunk    307, total features collected:    20920
# Memory usage: 719.08 MB
# Processed chunk    308, total features collected:    20920
# Memory usage: 720.30 MB
# Processed chunk    309, total features collected:    20920
# Memory usage: 721.12 MB
# Processed chunk    310, total features collected:    20920
# Memory usage: 722.97 MB
# Processed chunk    311, total features collected:    20920
# Memory usage: 725.00 MB
# Processed chunk    312, total features collected:    20920
# Memory usage: 726.30 MB
# Processed chunk    313, total features collected:    20920
# Memory usage: 727.06 MB
# Processed chunk    314, total features collected:    20920
# Memory usage: 731.02 MB
# Processed chunk    315, total features collected:    20920
# Memory usage: 731.97 MB
# Processed chunk    316, total features collected:    20920
# Memory usage: 712.84 MB
# Processed chunk    317, total features collected:    20920
# Memory usage: 714.17 MB
# Processed chunk    318, total features collected:    20920
# Memory usage: 716.48 MB
# Processed chunk    319, total features collected:    20920
# Memory usage: 717.64 MB
# Processed chunk    320, total features collected:    20920
# Memory usage: 718.91 MB
# Processed chunk    321, total features collected:    20920
# Memory usage: 719.97 MB
# Processed chunk    322, total features collected:    20920
# Memory usage: 721.64 MB
# Processed chunk    323, total features collected:    20920
# Memory usage: 723.05 MB
# Processed chunk    324, total features collected:    20920
# Memory usage: 723.94 MB
# Processed chunk    325, total features collected:    20920
# Memory usage: 724.78 MB
# Processed chunk    326, total features collected:    20920
# Memory usage: 725.97 MB
# Processed chunk    327, total features collected:    20920
# Memory usage: 727.03 MB
# Processed chunk    328, total features collected:    20920
# Memory usage: 727.80 MB
# Processed chunk    329, total features collected:    20920
# Memory usage: 729.23 MB
# Processed chunk    330, total features collected:    20920
# Memory usage: 729.66 MB
# Processed chunk    331, total features collected:    20920
# Memory usage: 730.69 MB
# Processed chunk    332, total features collected:    20920
# Memory usage: 731.86 MB
# Processed chunk    333, total features collected:    20920
# Memory usage: 733.20 MB
# Processed chunk    334, total features collected:    20920
# Memory usage: 734.22 MB
# Processed chunk    335, total features collected:    20920
# Memory usage: 735.64 MB
# Processed chunk    336, total features collected:    20920
# Memory usage: 736.75 MB
# Processed chunk    337, total features collected:    20920
# Memory usage: 737.34 MB
# Processed chunk    338, total features collected:    20920
# Memory usage: 738.47 MB
# Processed chunk    339, total features collected:    20920
# Memory usage: 741.19 MB
# Processed chunk    340, total features collected:    20920
# Memory usage: 741.91 MB
# Processed chunk    341, total features collected:    20920
# Memory usage: 743.14 MB
# Processed chunk    342, total features collected:    20920
# Memory usage: 744.45 MB
# Processed chunk    343, total features collected:    20920
# Memory usage: 745.75 MB
# Processed chunk    344, total features collected:    20920
# Memory usage: 746.22 MB
# Processed chunk    345, total features collected:    20920
# Memory usage: 747.61 MB
# Processed chunk    346, total features collected:    20920
# Memory usage: 748.30 MB
# Processed chunk    347, total features collected:    20920
# Memory usage: 748.75 MB
# Processed chunk    348, total features collected:    20920
# Memory usage: 747.66 MB
# Processed chunk    349, total features collected:    20920
# Memory usage: 749.06 MB
# Processed chunk    350, total features collected:    20920
# Memory usage: 749.73 MB
# Processed chunk    351, total features collected:    20920
# Memory usage: 750.47 MB
# Processed chunk    352, total features collected:    20920
# Memory usage: 751.59 MB
# Processed chunk    353, total features collected:    20920
# Memory usage: 752.59 MB
# Processed chunk    354, total features collected:    20920
# Memory usage: 753.80 MB
# Processed chunk    355, total features collected:    20920
# Memory usage: 754.98 MB
# Processed chunk    356, total features collected:    20920
# Memory usage: 755.86 MB
# Processed chunk    357, total features collected:    20920
# Memory usage: 757.17 MB
# Processed chunk    358, total features collected:    20920
# Memory usage: 758.48 MB
# Processed chunk    359, total features collected:    20920
# Memory usage: 755.20 MB
# Processed chunk    360, total features collected:    20920
# Memory usage: 756.23 MB
# Processed chunk    361, total features collected:    20920
# Memory usage: 757.58 MB
# Processed chunk    362, total features collected:    20920
# Memory usage: 759.09 MB
# Processed chunk    363, total features collected:    20920
# Memory usage: 759.95 MB
# Processed chunk    364, total features collected:    20920
# Memory usage: 761.23 MB
# Processed chunk    365, total features collected:    20920
# Memory usage: 762.23 MB
# Processed chunk    366, total features collected:    20920
# Memory usage: 764.02 MB
# Processed chunk    367, total features collected:    20920
# Memory usage: 765.59 MB
# Processed chunk    368, total features collected:    20920
# Memory usage: 766.27 MB
# Processed chunk    369, total features collected:    20920
# Memory usage: 767.61 MB
# Processed chunk    370, total features collected:    20920
# Memory usage: 769.88 MB
# Processed chunk    371, total features collected:    20920
# Memory usage: 771.67 MB
# Processed chunk    372, total features collected:    20920
# Memory usage: 772.14 MB
# Processed chunk    373, total features collected:    20920
# Memory usage: 772.97 MB
# Processed chunk    374, total features collected:    20920
# Memory usage: 774.27 MB
# Processed chunk    375, total features collected:    20920
# Memory usage: 775.56 MB
# Processed chunk    376, total features collected:    20920
# Memory usage: 777.17 MB
# Processed chunk    377, total features collected:    20920
# Memory usage: 778.34 MB
# Processed chunk    378, total features collected:    20920
# Memory usage: 779.80 MB
# Processed chunk    379, total features collected:    20920
# Memory usage: 780.44 MB
# Processed chunk    380, total features collected:    20920
# Memory usage: 781.05 MB
# Processed chunk    381, total features collected:    20920
# Memory usage: 763.67 MB
# Processed chunk    382, total features collected:    20920
# Memory usage: 764.50 MB
# Processed chunk    383, total features collected:    20920
# Memory usage: 765.97 MB
# Processed chunk    384, total features collected:    20920
# Memory usage: 767.17 MB
# Processed chunk    385, total features collected:    20920
# Memory usage: 768.73 MB
# Processed chunk    386, total features collected:    20920
# Memory usage: 770.22 MB
# Processed chunk    387, total features collected:    20920
# Memory usage: 771.08 MB
# Processed chunk    388, total features collected:    20920
# Memory usage: 772.20 MB
# Processed chunk    389, total features collected:    20920
# Memory usage: 760.66 MB
# Processed chunk    390, total features collected:    20920
# Memory usage: 733.97 MB
# Processed chunk    391, total features collected:    20920
# Memory usage: 735.73 MB
# Processed chunk    392, total features collected:    20920
# Memory usage: 737.25 MB
# Processed chunk    393, total features collected:    20920
# Memory usage: 738.81 MB
# Processed chunk    394, total features collected:    20920
# Memory usage: 739.58 MB
# Processed chunk    395, total features collected:    20920
# Memory usage: 741.36 MB
# Processed chunk    396, total features collected:    20920
# Memory usage: 742.50 MB
# Processed chunk    397, total features collected:    20920
# Memory usage: 744.38 MB
# Processed chunk    398, total features collected:    20920
# Memory usage: 746.72 MB
# Processed chunk    399, total features collected:    20920
# Memory usage: 747.66 MB
# Processed chunk    400, total features collected:    20920
# Memory usage: 722.95 MB
# Processed chunk    401, total features collected:    20920
# Memory usage: 723.75 MB
# Processed chunk    402, total features collected:    20920
# Memory usage: 642.05 MB
# Processed chunk    403, total features collected:    20920
# Memory usage: 605.52 MB
# Processed chunk    404, total features collected:    20920
# Memory usage: 608.09 MB
# Processed chunk    405, total features collected:    20920
# Memory usage: 612.62 MB
# Processed chunk    406, total features collected:    20920
# Memory usage: 616.98 MB
# Processed chunk    407, total features collected:    20920
# Memory usage: 622.97 MB
# Processed chunk    408, total features collected:    20920
# Memory usage: 625.81 MB
# Processed chunk    409, total features collected:    20920
# Memory usage: 626.67 MB
# Processed chunk    410, total features collected:    20920
# Memory usage: 622.27 MB
# Processed chunk    411, total features collected:    20920
# Memory usage: 625.84 MB
# Processed chunk    412, total features collected:    20920
# Memory usage: 627.06 MB
# Processed chunk    413, total features collected:    20920
# Memory usage: 629.48 MB
# Processed chunk    414, total features collected:    20920
# Memory usage: 631.09 MB
# Processed chunk    415, total features collected:    20920
# Memory usage: 631.73 MB
# Processed chunk    416, total features collected:    20920
# Memory usage: 630.50 MB
# Processed chunk    417, total features collected:    20920
# Memory usage: 632.58 MB
# Processed chunk    418, total features collected:    20920
# Memory usage: 635.30 MB
# Processed chunk    419, total features collected:    20920
# Memory usage: 636.61 MB
# Processed chunk    420, total features collected:    20920
# Memory usage: 638.52 MB
# Processed chunk    421, total features collected:    20920
# Memory usage: 639.78 MB
# Processed chunk    422, total features collected:    20920
# Memory usage: 641.34 MB
# Processed chunk    423, total features collected:    20920
# Memory usage: 643.06 MB
# Processed chunk    424, total features collected:    20920
# Memory usage: 643.89 MB
# Processed chunk    425, total features collected:    20920
# Memory usage: 645.12 MB
# Processed chunk    426, total features collected:    20920
# Memory usage: 645.89 MB
# Processed chunk    427, total features collected:    20920
# Memory usage: 647.06 MB
# Processed chunk    428, total features collected:    20920
# Memory usage: 648.31 MB
# Processed chunk    429, total features collected:    20920
# Memory usage: 649.73 MB
# Processed chunk    430, total features collected:    20920
# Memory usage: 650.81 MB
# Processed chunk    431, total features collected:    20920
# Memory usage: 652.28 MB
# Processed chunk    432, total features collected:    20920
# Memory usage: 653.67 MB
# Processed chunk    433, total features collected:    20920
# Memory usage: 655.38 MB
# Processed chunk    434, total features collected:    20920
# Memory usage: 657.22 MB
# Processed chunk    435, total features collected:    20920
# Memory usage: 658.19 MB
# Processed chunk    436, total features collected:    20920
# Memory usage: 659.58 MB
# Processed chunk    437, total features collected:    20920
# Memory usage: 660.17 MB
# Processed chunk    438, total features collected:    20920
# Memory usage: 661.33 MB
# Processed chunk    439, total features collected:    20920
# Memory usage: 662.27 MB
# Processed chunk    440, total features collected:    20920
# Memory usage: 662.75 MB
# Processed chunk    441, total features collected:    20920
# Memory usage: 664.23 MB
# Processed chunk    442, total features collected:    20920
# Memory usage: 665.84 MB
# Processed chunk    443, total features collected:    20920
# Memory usage: 668.16 MB
# Processed chunk    444, total features collected:    20920
# Memory usage: 669.19 MB
# Processed chunk    445, total features collected:    20920
# Memory usage: 671.45 MB
# Processed chunk    446, total features collected:    20920
# Memory usage: 672.28 MB
# Processed chunk    447, total features collected:    20920
# Memory usage: 673.81 MB
# Processed chunk    448, total features collected:    20920
# Memory usage: 675.14 MB
# Processed chunk    449, total features collected:    20920
# Memory usage: 676.08 MB
# Processed chunk    450, total features collected:    20920
# Memory usage: 678.20 MB
# Processed chunk    451, total features collected:    20920
# Memory usage: 679.03 MB
# Processed chunk    452, total features collected:    20920
# Memory usage: 680.75 MB
# Processed chunk    453, total features collected:    20920
# Memory usage: 681.55 MB
# Processed chunk    454, total features collected:    20920
# Memory usage: 682.77 MB
# Processed chunk    455, total features collected:    20920
# Memory usage: 684.20 MB
# Processed chunk    456, total features collected:    20920
# Memory usage: 685.47 MB
# Processed chunk    457, total features collected:    20920
# Memory usage: 686.30 MB
# Processed chunk    458, total features collected:    20920
# Memory usage: 687.62 MB
# Processed chunk    459, total features collected:    20920
# Memory usage: 688.59 MB
# Processed chunk    460, total features collected:    20920
# Memory usage: 685.23 MB
# Processed chunk    461, total features collected:    20920
# Memory usage: 686.58 MB
# Processed chunk    462, total features collected:    20920
# Memory usage: 687.39 MB
# Processed chunk    463, total features collected:    20920
# Memory usage: 681.92 MB
# Processed chunk    464, total features collected:    20920
# Memory usage: 678.58 MB
# Processed chunk    465, total features collected:    20920
# Memory usage: 679.59 MB
# Processed chunk    466, total features collected:    20920
# Memory usage: 681.41 MB
# Processed chunk    467, total features collected:    20920
# Memory usage: 682.12 MB
# Processed chunk    468, total features collected:    20920
# Memory usage: 683.28 MB
# Processed chunk    469, total features collected:    20920
# Memory usage: 685.06 MB
# Processed chunk    470, total features collected:    20920
# Memory usage: 685.73 MB
# Processed chunk    471, total features collected:    20920
# Memory usage: 686.84 MB
# Processed chunk    472, total features collected:    20920
# Memory usage: 688.94 MB
# Processed chunk    473, total features collected:    20920
# Memory usage: 690.22 MB
# Processed chunk    474, total features collected:    20920
# Memory usage: 691.55 MB
# Processed chunk    475, total features collected:    20920
# Memory usage: 692.56 MB
# Processed chunk    476, total features collected:    21541
# Memory usage: 695.30 MB
# Processed chunk    477, total features collected:    21855
# Memory usage: 696.69 MB
# Processed chunk    478, total features collected:    21855
# Memory usage: 699.00 MB
# Processed chunk    479, total features collected:    21855
# Memory usage: 702.09 MB
# Processed chunk    480, total features collected:    21855
# Memory usage: 703.78 MB
# Processed chunk    481, total features collected:    21855
# Memory usage: 705.89 MB
# Processed chunk    482, total features collected:    21855
# Memory usage: 706.97 MB
# Processed chunk    483, total features collected:    21855
# Memory usage: 710.97 MB
# Processed chunk    484, total features collected:    21855
# Memory usage: 711.84 MB
# Processed chunk    485, total features collected:    21855
# Memory usage: 712.78 MB
# Processed chunk    486, total features collected:    21855
# Memory usage: 714.44 MB
# Processed chunk    487, total features collected:    21855
# Memory usage: 715.67 MB
# Processed chunk    488, total features collected:    21855
# Memory usage: 717.59 MB
# Processed chunk    489, total features collected:    21855
# Memory usage: 718.75 MB
# Processed chunk    490, total features collected:    21855
# Memory usage: 719.89 MB
# Processed chunk    491, total features collected:    21855
# Memory usage: 720.94 MB
# Processed chunk    492, total features collected:    21855
# Memory usage: 722.20 MB
# Processed chunk    493, total features collected:    21855
# Memory usage: 724.05 MB
# Processed chunk    494, total features collected:    21855
# Memory usage: 727.23 MB
# Processed chunk    495, total features collected:    21855
# Memory usage: 728.66 MB
# Processed chunk    496, total features collected:    21855
# Memory usage: 729.53 MB
# Processed chunk    497, total features collected:    21855
# Memory usage: 730.70 MB
# Processed chunk    498, total features collected:    21855
# Memory usage: 732.28 MB
# Processed chunk    499, total features collected:    21855
# Memory usage: 732.89 MB
# Processed chunk    500, total features collected:    21855
# Memory usage: 733.53 MB
# Processed chunk    501, total features collected:    21855
# Memory usage: 734.95 MB
# Processed chunk    502, total features collected:    21855
# Memory usage: 736.27 MB
# Processed chunk    503, total features collected:    21855
# Memory usage: 737.38 MB
# Processed chunk    504, total features collected:    21855
# Memory usage: 738.14 MB
# Processed chunk    505, total features collected:    21855
# Memory usage: 738.94 MB
# Processed chunk    506, total features collected:    21855
# Memory usage: 740.23 MB
# Processed chunk    507, total features collected:    21855
# Memory usage: 741.75 MB
# Processed chunk    508, total features collected:    21855
# Memory usage: 743.33 MB
# Processed chunk    509, total features collected:    21855
# Memory usage: 744.62 MB
# Processed chunk    510, total features collected:    21855
# Memory usage: 746.58 MB
# Processed chunk    511, total features collected:    21855
# Memory usage: 747.66 MB
# Processed chunk    512, total features collected:    21855
# Memory usage: 748.91 MB
# Processed chunk    513, total features collected:    21855
# Memory usage: 750.33 MB
# Processed chunk    514, total features collected:    21855
# Memory usage: 751.03 MB
# Processed chunk    515, total features collected:    21855
# Memory usage: 752.20 MB
# Processed chunk    516, total features collected:    21855
# Memory usage: 753.27 MB
# Processed chunk    517, total features collected:    21855
# Memory usage: 755.98 MB
# Processed chunk    518, total features collected:    21855
# Memory usage: 756.55 MB
# Processed chunk    519, total features collected:    21855
# Memory usage: 757.58 MB
# Processed chunk    520, total features collected:    21855
# Memory usage: 758.75 MB
# Processed chunk    521, total features collected:    21855
# Memory usage: 760.08 MB
# Processed chunk    522, total features collected:    21855
# Memory usage: 762.62 MB
# Processed chunk    523, total features collected:    21855
# Memory usage: 763.58 MB
# Processed chunk    524, total features collected:    21855
# Memory usage: 764.89 MB
# Processed chunk    525, total features collected:    21855
# Memory usage: 765.66 MB
# Processed chunk    526, total features collected:    21855
# Memory usage: 766.70 MB
# Processed chunk    527, total features collected:    21855
# Memory usage: 767.86 MB
# Processed chunk    528, total features collected:    21855
# Memory usage: 769.55 MB
# Processed chunk    529, total features collected:    21855
# Memory usage: 770.78 MB
# Processed chunk    530, total features collected:    21855
# Memory usage: 772.78 MB
# Processed chunk    531, total features collected:    21855
# Memory usage: 774.31 MB
# Processed chunk    532, total features collected:    21855
# Memory usage: 778.00 MB
# Processed chunk    533, total features collected:    21855
# Memory usage: 781.16 MB
# Processed chunk    534, total features collected:    21855
# Memory usage: 782.19 MB
# Processed chunk    535, total features collected:    21855
# Memory usage: 783.19 MB
# Processed chunk    536, total features collected:    21855
# Memory usage: 785.00 MB
# Processed chunk    537, total features collected:    21855
# Memory usage: 786.06 MB
# Processed chunk    538, total features collected:    21855
# Memory usage: 787.77 MB
# Processed chunk    539, total features collected:    21855
# Memory usage: 952.00 MB
# Processed chunk    540, total features collected:    21855
# Memory usage: 956.42 MB
# Processed chunk    541, total features collected:    21855
# Memory usage: 957.11 MB
# Processed chunk    542, total features collected:    21855
# Memory usage: 959.11 MB
# Processed chunk    543, total features collected:    21855
# Memory usage: 960.28 MB
# Processed chunk    544, total features collected:    21855
# Memory usage: 961.23 MB
# Processed chunk    545, total features collected:    21855
# Memory usage: 962.50 MB
# Processed chunk    546, total features collected:    21855
# Memory usage: 964.02 MB
# Processed chunk    547, total features collected:    21855
# Memory usage: 965.20 MB
# Processed chunk    548, total features collected:    21855
# Memory usage: 967.38 MB
# Processed chunk    549, total features collected:    21855
# Memory usage: 969.48 MB
# Processed chunk    550, total features collected:    21855
# Memory usage: 972.08 MB
# Processed chunk    551, total features collected:    21855
# Memory usage: 972.95 MB
# Processed chunk    552, total features collected:    21855
# Memory usage: 974.11 MB
# Processed chunk    553, total features collected:    21855
# Memory usage: 977.83 MB
# Processed chunk    554, total features collected:    21855
# Memory usage: 979.14 MB
# Processed chunk    555, total features collected:    21855
# Memory usage: 980.48 MB
# Processed chunk    556, total features collected:    21855
# Memory usage: 981.47 MB
# Processed chunk    557, total features collected:    21855
# Memory usage: 983.66 MB
# Processed chunk    558, total features collected:    21889
# Memory usage: 984.44 MB
# Processed chunk    559, total features collected:    21900
# Memory usage: 985.98 MB
# Processed chunk    560, total features collected:    22355
# Memory usage: 988.64 MB
# Processed chunk    561, total features collected:    22355
# Memory usage: 989.64 MB
# ...
# Memory usage: 497.23 MB
# Processed chunk  16004, total features collected:   618232
# Memory usage: 492.81 MB
# Processed chunk  16005, total features collected:   618232
# Memory usage: 496.53 MB
# Processed chunk  16006, total features collected:   618232
# Memory usage: 497.91 MB
# Processed chunk  16007, total features collected:   618232
# Memory usage: 499.23 MB
# Processed chunk  16008, total features collected:   618232
# Memory usage: 500.73 MB
# Processed chunk  16009, total features collected:   618232
# Memory usage: 501.52 MB
# Processed chunk  16010, total features collected:   618232
# Memory usage: 503.14 MB
# Processed chunk  16011, total features collected:   618232
# Memory usage: 498.58 MB
# Processed chunk  16012, total features collected:   618232
# Memory usage: 490.45 MB
# Processed chunk  16013, total features collected:   618232
# Memory usage: 491.64 MB
# Processed chunk  16014, total features collected:   618232
# Memory usage: 492.80 MB
# Processed chunk  16015, total features collected:   618232
# Memory usage: 496.56 MB
# Processed chunk  16016, total features collected:   618232
# Memory usage: 498.27 MB
# Processed chunk  16017, total features collected:   618232
# Memory usage: 498.91 MB
# Processed chunk  16018, total features collected:   618232
# Memory usage: 501.12 MB
# Processed chunk  16019, total features collected:   618232
# Memory usage: 501.62 MB
# Processed chunk  16020, total features collected:   618232
# Memory usage: 503.05 MB
# Processed chunk  16021, total features collected:   618232
# Memory usage: 504.69 MB
# Processed chunk  16022, total features collected:   618232
# Memory usage: 505.62 MB
# Processed chunk  16023, total features collected:   618232
# Memory usage: 503.53 MB
# Processed chunk  16024, total features collected:   618232
# Memory usage: 504.33 MB
# Processed chunk  16025, total features collected:   618232
# Memory usage: 507.31 MB
# Processed chunk  16026, total features collected:   618232
# Memory usage: 508.67 MB
# Processed chunk  16027, total features collected:   618232
# Memory usage: 509.47 MB
# Processed chunk  16028, total features collected:   618232
# Memory usage: 511.30 MB
# Processed chunk  16029, total features collected:   618232
# Memory usage: 511.88 MB
# Processed chunk  16030, total features collected:   618232
# Memory usage: 513.44 MB
# Processed chunk  16031, total features collected:   618232
# Memory usage: 514.95 MB
# Processed chunk  16032, total features collected:   618232
# Memory usage: 517.06 MB
# Processed chunk  16033, total features collected:   618232
# Memory usage: 507.64 MB
# Processed chunk  16034, total features collected:   618232
# Memory usage: 508.98 MB
# Processed chunk  16035, total features collected:   618232
# Memory usage: 510.44 MB
# Processed chunk  16036, total features collected:   618232
# Memory usage: 513.12 MB
# Processed chunk  16037, total features collected:   618232
# Memory usage: 514.59 MB
# Processed chunk  16038, total features collected:   618232
# Memory usage: 515.84 MB
# Processed chunk  16039, total features collected:   618232
# Memory usage: 517.56 MB
# Processed chunk  16040, total features collected:   618232
# Memory usage: 517.89 MB
# Processed chunk  16041, total features collected:   618232
# Memory usage: 518.89 MB
# Processed chunk  16042, total features collected:   618232
# Memory usage: 521.56 MB
# Processed chunk  16043, total features collected:   618232
# Memory usage: 524.05 MB
# Processed chunk  16044, total features collected:   618232
# Memory usage: 525.34 MB
# Processed chunk  16045, total features collected:   618232
# Memory usage: 526.08 MB
# Processed chunk  16046, total features collected:   618232
# Memory usage: 527.84 MB
# Processed chunk  16047, total features collected:   618232
# Memory usage: 528.33 MB
# Processed chunk  16048, total features collected:   618232
# Memory usage: 526.89 MB
# Processed chunk  16049, total features collected:   618232
# Memory usage: 527.44 MB
# Processed chunk  16050, total features collected:   618232
# Memory usage: 528.61 MB
# Processed chunk  16051, total features collected:   618232
# Memory usage: 529.58 MB
# Processed chunk  16052, total features collected:   618232
# Memory usage: 530.75 MB
# Processed chunk  16053, total features collected:   618232
# Memory usage: 531.38 MB
# Processed chunk  16054, total features collected:   618694
# Memory usage: 533.08 MB
# Processed chunk  16055, total features collected:   618694
# Memory usage: 536.19 MB
# Processed chunk  16056, total features collected:   618694
# Memory usage: 537.17 MB
# Processed chunk  16057, total features collected:   618694
# Memory usage: 538.62 MB
# Processed chunk  16058, total features collected:   618694
# Memory usage: 540.42 MB
# Processed chunk  16059, total features collected:   618694
# Memory usage: 480.00 MB
# Processed chunk  16060, total features collected:   618694
# Memory usage: 490.88 MB
# Processed chunk  16061, total features collected:   618694
# Memory usage: 492.92 MB
# Processed chunk  16062, total features collected:   618694
# Memory usage: 492.97 MB
# Processed chunk  16063, total features collected:   618694
# Memory usage: 495.95 MB
# Processed chunk  16064, total features collected:   618694
# Memory usage: 499.94 MB
# Processed chunk  16065, total features collected:   618694
# Memory usage: 501.97 MB
# Processed chunk  16066, total features collected:   618694
# Memory usage: 504.42 MB
# Processed chunk  16067, total features collected:   618694
# Memory usage: 505.70 MB
# Processed chunk  16068, total features collected:   618694
# Memory usage: 508.45 MB
# Processed chunk  16069, total features collected:   618694
# Memory usage: 511.86 MB
# Processed chunk  16070, total features collected:   618694
# Memory usage: 479.66 MB
# Processed chunk  16071, total features collected:   618694
# Memory usage: 478.50 MB
# Processed chunk  16072, total features collected:   618694
# Memory usage: 485.33 MB
# Processed chunk  16073, total features collected:   618694
# Memory usage: 486.78 MB
# Processed chunk  16074, total features collected:   618694
# Memory usage: 488.22 MB
# Processed chunk  16075, total features collected:   618694
# Memory usage: 489.52 MB
# Processed chunk  16076, total features collected:   618694
# Memory usage: 428.89 MB
# Processed chunk  16077, total features collected:   618694
# Memory usage: 435.30 MB
# Processed chunk  16078, total features collected:   618694
# Memory usage: 428.02 MB
# Processed chunk  16079, total features collected:   618694
# Memory usage: 429.59 MB
# Processed chunk  16080, total features collected:   618694
# Memory usage: 434.20 MB
# Processed chunk  16081, total features collected:   618694
# Memory usage: 436.38 MB
# Processed chunk  16082, total features collected:   618694
# Memory usage: 439.58 MB
# Processed chunk  16083, total features collected:   618694
# Memory usage: 440.62 MB
# Processed chunk  16084, total features collected:   618694
# Memory usage: 441.67 MB
# Processed chunk  16085, total features collected:   618694
# Memory usage: 443.25 MB
# Processed chunk  16086, total features collected:   618694
# Memory usage: 444.50 MB
# Processed chunk  16087, total features collected:   618694
# Memory usage: 445.81 MB
# Processed chunk  16088, total features collected:   618694
# Memory usage: 447.14 MB
# Processed chunk  16089, total features collected:   618694
# Memory usage: 442.02 MB
# Processed chunk  16090, total features collected:   618694
# Memory usage: 443.31 MB
# Processed chunk  16091, total features collected:   618694
# Memory usage: 445.05 MB
# Processed chunk  16092, total features collected:   618694
# Memory usage: 446.89 MB
# Processed chunk  16093, total features collected:   618694
# Memory usage: 448.73 MB
# Processed chunk  16094, total features collected:   618694
# Memory usage: 452.75 MB
# Processed chunk  16095, total features collected:   618694
# Memory usage: 443.77 MB
# Processed chunk  16096, total features collected:   618694
# Memory usage: 445.12 MB
# Processed chunk  16097, total features collected:   618694
# Memory usage: 435.53 MB
# Processed chunk  16098, total features collected:   618694
# Memory usage: 437.50 MB
# Processed chunk  16099, total features collected:   618694
# Memory usage: 438.41 MB
# Processed chunk  16100, total features collected:   618694
# Memory usage: 439.84 MB
# Processed chunk  16101, total features collected:   618694
# Memory usage: 440.73 MB
# Processed chunk  16102, total features collected:   618694
# Memory usage: 442.11 MB
# Processed chunk  16103, total features collected:   618694
# Memory usage: 443.34 MB
# Processed chunk  16104, total features collected:   618694
# Memory usage: 445.58 MB
# Processed chunk  16105, total features collected:   618694
# Memory usage: 446.59 MB
# Processed chunk  16106, total features collected:   618694
# Memory usage: 447.39 MB
# Processed chunk  16107, total features collected:   618694
# Memory usage: 449.30 MB
# Processed chunk  16108, total features collected:   618694
# Memory usage: 448.61 MB
# Processed chunk  16109, total features collected:   618694
# Memory usage: 450.06 MB
# Processed chunk  16110, total features collected:   618694
# Memory usage: 453.36 MB
# Processed chunk  16111, total features collected:   618694
# Memory usage: 454.11 MB
# Processed chunk  16112, total features collected:   618694
# Memory usage: 456.20 MB
# Processed chunk  16113, total features collected:   618694
# Memory usage: 458.36 MB
# Processed chunk  16114, total features collected:   618694
# Memory usage: 459.34 MB
# Processed chunk  16115, total features collected:   618694
# Memory usage: 460.47 MB
# Processed chunk  16116, total features collected:   618694
# Memory usage: 462.27 MB
# Processed chunk  16117, total features collected:   618694
# Memory usage: 465.02 MB
# Processed chunk  16118, total features collected:   618694
# Memory usage: 465.92 MB
# Processed chunk  16119, total features collected:   618694
# Memory usage: 467.17 MB
# Processed chunk  16120, total features collected:   618694
# Memory usage: 471.59 MB
# Processed chunk  16121, total features collected:   618694
# Memory usage: 472.14 MB
# Processed chunk  16122, total features collected:   618694
# Memory usage: 473.28 MB
# Processed chunk  16123, total features collected:   618694
# Memory usage: 474.33 MB
# Processed chunk  16124, total features collected:   618694
# Memory usage: 475.53 MB
# Processed chunk  16125, total features collected:   618694
# Memory usage: 476.58 MB
# Processed chunk  16126, total features collected:   618694
# Memory usage: 479.02 MB
# Processed chunk  16127, total features collected:   618694
# Memory usage: 482.81 MB
# Processed chunk  16128, total features collected:   618694
# Memory usage: 484.62 MB
# Processed chunk  16129, total features collected:   618694
# Memory usage: 486.23 MB
# Processed chunk  16130, total features collected:   618694
# Memory usage: 489.94 MB
# Processed chunk  16131, total features collected:   618694
# Memory usage: 491.27 MB
# Processed chunk  16132, total features collected:   618694
# Memory usage: 494.72 MB
# Processed chunk  16133, total features collected:   618694
# Memory usage: 497.14 MB
# Processed chunk  16134, total features collected:   618694
# Memory usage: 501.39 MB
# Processed chunk  16135, total features collected:   618694
# Memory usage: 503.55 MB
# Processed chunk  16136, total features collected:   618694
# Memory usage: 505.33 MB
# Processed chunk  16137, total features collected:   618694
# Memory usage: 506.95 MB
# Processed chunk  16138, total features collected:   618694
# Memory usage: 509.03 MB
# Processed chunk  16139, total features collected:   618694
# Memory usage: 511.36 MB
# Processed chunk  16140, total features collected:   618694
# Memory usage: 513.34 MB
# Processed chunk  16141, total features collected:   618694
# Memory usage: 515.48 MB
# Processed chunk  16142, total features collected:   618694
# Memory usage: 516.72 MB
# Processed chunk  16143, total features collected:   618694
# Memory usage: 517.53 MB
# Processed chunk  16144, total features collected:   618694
# Memory usage: 518.33 MB
# Processed chunk  16145, total features collected:   618694
# Memory usage: 519.33 MB
# Processed chunk  16146, total features collected:   618694
# Memory usage: 519.89 MB
# Processed chunk  16147, total features collected:   618694
# Memory usage: 522.16 MB
# Processed chunk  16148, total features collected:   618694
# Memory usage: 525.84 MB
# Processed chunk  16149, total features collected:   618694
# Memory usage: 527.78 MB
# Processed chunk  16150, total features collected:   618694
# Memory usage: 528.58 MB
# Processed chunk  16151, total features collected:   618694
# Memory usage: 529.86 MB
# Processed chunk  16152, total features collected:   618694
# Memory usage: 532.52 MB
# Processed chunk  16153, total features collected:   618694
# Memory usage: 533.11 MB
# Processed chunk  16154, total features collected:   618694
# Memory usage: 535.19 MB
# Processed chunk  16155, total features collected:   618694
# Memory usage: 535.70 MB
# Processed chunk  16156, total features collected:   618694
# Memory usage: 537.30 MB
# Processed chunk  16157, total features collected:   618694
# Memory usage: 537.97 MB
# Processed chunk  16158, total features collected:   618694
# Memory usage: 539.20 MB
# Processed chunk  16159, total features collected:   618694
# Memory usage: 540.50 MB
# Processed chunk  16160, total features collected:   618694
# Memory usage: 541.56 MB
# Processed chunk  16161, total features collected:   618694
# Memory usage: 542.17 MB
# Processed chunk  16162, total features collected:   618694
# Memory usage: 543.31 MB
# Processed chunk  16163, total features collected:   618694
# Memory usage: 544.36 MB
# Processed chunk  16164, total features collected:   618694
# Memory usage: 546.66 MB
# Processed chunk  16165, total features collected:   618694
# Memory usage: 547.73 MB
# Processed chunk  16166, total features collected:   618694
# Memory usage: 532.73 MB
# Processed chunk  16167, total features collected:   618694
# Memory usage: 517.81 MB
# Processed chunk  16168, total features collected:   618694
# Memory usage: 519.02 MB
# Processed chunk  16169, total features collected:   618694
# Memory usage: 522.33 MB
# Processed chunk  16170, total features collected:   618694
# Memory usage: 523.89 MB
# Processed chunk  16171, total features collected:   618694
# Memory usage: 524.31 MB
# Processed chunk  16172, total features collected:   618694
# Memory usage: 525.88 MB
# Processed chunk  16173, total features collected:   618694
# Memory usage: 519.05 MB
# Processed chunk  16174, total features collected:   618694
# Memory usage: 522.25 MB
# Processed chunk  16175, total features collected:   618694
# Memory usage: 523.16 MB
# Processed chunk  16176, total features collected:   618694
# Memory usage: 524.17 MB
# Processed chunk  16177, total features collected:   618694
# Memory usage: 511.02 MB
# Processed chunk  16178, total features collected:   618694
# Memory usage: 475.70 MB
# Processed chunk  16179, total features collected:   618694
# Memory usage: 474.33 MB
# Processed chunk  16180, total features collected:   618694
# Memory usage: 475.08 MB
# Processed chunk  16181, total features collected:   618694
# Memory usage: 476.17 MB
# Processed chunk  16182, total features collected:   618694
# Memory usage: 479.12 MB
# Processed chunk  16183, total features collected:   618694
# Memory usage: 480.47 MB
# Processed chunk  16184, total features collected:   618694
# Memory usage: 484.30 MB
# Processed chunk  16185, total features collected:   618694
# Memory usage: 486.19 MB
# Processed chunk  16186, total features collected:   618694
# Memory usage: 487.23 MB
# Processed chunk  16187, total features collected:   618694
# Memory usage: 489.09 MB
# Processed chunk  16188, total features collected:   618694
# Memory usage: 490.45 MB
# Processed chunk  16189, total features collected:   618694
# Memory usage: 494.23 MB
# Processed chunk  16190, total features collected:   618694
# Memory usage: 495.48 MB
# Processed chunk  16191, total features collected:   618694
# Memory usage: 468.25 MB
# Processed chunk  16192, total features collected:   618694
# Memory usage: 469.86 MB
# Processed chunk  16193, total features collected:   618694
# Memory usage: 472.08 MB
# Processed chunk  16194, total features collected:   618694
# Memory usage: 472.73 MB
# Processed chunk  16195, total features collected:   618694
# Memory usage: 473.58 MB
# Script execution time: 1533.83 seconds

# %%
gdf_selected.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 85640 entries, 0 to 85639
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CSBID      85640 non-null  object
#  1   CSBYEARS   85640 non-null  object
#  2   CSBACRES   85640 non-null  float64
#  3   CDL2016    85640 non-null  int64
#  4   CDL2017    85640 non-null  int64
#  5   CDL2018    85640 non-null  int64
#  6   CDL2019    85640 non-null  int64
#  7   CDL2020    85640 non-null  int64
#  8   CDL2021    85640 non-null  int64
#  9   CDL2022    85640 non-null  int64
#  10  CDL2023    85640 non-null  int64
#  11  STATEFIPS  85640 non-null  object
#  12  STATEASD   85640 non-null  object
#  13  ASD        85640 non-null  object
#  14  CNTY       85640 non-null  object
#  15  CNTYFIPS   85640 non-null  object
#  16  INSIDE_X   85640 non-null  float64
#  17  INSIDE_Y   85640 non-null  float64
#  18  Shp_Len    85640 non-null  float64
#  19  Shp_Area   85640 non-null  float64
#  20  geometry   85640 non-null  geometry
# dtypes: float64(5), geometry(1), int64(8), object(7)
# memory usage: 13.7+ MB
