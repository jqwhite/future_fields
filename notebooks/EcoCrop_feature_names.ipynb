# %%
import pandas as pd
import geopandas as gpd

# %%
# ecocrop_variables = pd.read_csv('../data/agricultural/EcoCrop/OpenCLIM/Ecocrop_variable_lookup.csv')
ecocrop_variables = pd.read_csv('../data/crops/Ecocrop_variable_lookup.csv')

# %%
ecocrop_variables
# Out:
#    Variable                       Explanation
# 0      AUTH                         Authority
# 1   FAMNAME                            Family
# 2      SYNO                          Synonyms
# 3   COMNAME                      Common names
# 4      LIFO                         Life form
# 5      HABI                           Habitat
# 6     LISPA                         Life span
# 7      PHYS                        Physiology
# 8       CAT                          Category
# 9      PLAT                  Plant attributes
# 10    TOPMN       optimal minimum temperature
# 11    TOPMX       optimal maximum temperature
# 12     TMIN      absolute minimum temperature
# 13     TMAX      absolute maximum temperature
# 14    ROPMN          optimal minimum rainfall
# 15    ROPMX          optimal maximum rainfall
# 16     RMIN         absolute minimum rainfall
# 17     RMAX         absolute maximum rainfall
# 18   PHOPMN           optimal minimum soil PH
# 19   PHOPMX           optimal maximum soil PH
# 20    PHMIN          absolute minimum soil PH
# 21    PHMAX          absolute maximum soil PH
# 22  LATOPMN          optimal minimum latitude
# 23  LATOPMX          optimal maximum latitude
# 24    LATMN         absolute minimum latitude
# 25    LATMX         absolute maximum latitude
# 26    ALTMX         absolute maximum altitude
# 27   LIOPMN   optimal minimum light intensity
# 28   LIOPMX   optimal maximum light intensity
# 29     LIMN  absolute minimum light intensity
# 30     LIMX  absolute maximum light intensity
# 31      DEP                Optimal soil depth
# 32     DEPR               Absolute soil depth
# 33     TEXT              Optimal soil texture
# 34    TEXTR             Absolute soil texture
# 35      FER            Optimal soil fertility
# 36     FERR           Absolute soil fertility
# 37      TOX   Optimal soil aluminium toxicity
# 38     TOXR  Absolute soil aluminium toxicity
# 39      SAL             Optimal soil salinity
# 40     SALR            Absolute soil salinity
# 41      DRA             Optimal soil drainage
# 42     DRAR            Absolute soil drainage
# 43    KTMPR   Killing temperature during rest
# 44     KTMP  Killing temperature early growth
# 45    PHOTO                       Photoperiod
# 46     CLIZ                      Climate zone
# 47   ABITOL                 Abiotic tolerance
# 48   ABISUS            Abiotic susceptibility
# 49    INTRI                 Introduction risk
# 50    PROSY                 Production system
# 51     GMIN                Minimum crop cycle
# 52     GMAX                Maximum crop cycle

# %%
list(ecocrop_variables["Explanation"])
# Out:
# ['Authority',
#  'Family',
#  'Synonyms',
#  'Common names',
#  'Life form',
#  'Habitat',
#  'Life span',
#  'Physiology',
#  'Category',
#  'Plant attributes',
#  'optimal minimum temperature',
#  'optimal maximum temperature',
#  'absolute minimum temperature',
#  'absolute maximum temperature',
#  'optimal minimum rainfall',
#  'optimal maximum rainfall',
#  'absolute minimum rainfall',
#  'absolute maximum rainfall',
#  'optimal minimum soil PH',
#  'optimal maximum soil PH',
#  'absolute minimum soil PH',
#  'absolute maximum soil PH',
#  'optimal minimum latitude',
#  'optimal maximum latitude',
#  'absolute minimum latitude',
#  'absolute maximum latitude',
#  'absolute maximum altitude',
#  'optimal minimum light intensity',
#  'optimal maximum light intensity',
#  'absolute minimum light intensity',
#  'absolute maximum light intensity',
#  'Optimal soil depth',
#  'Absolute soil depth',
#  'Optimal soil texture',
#  'Absolute soil texture',
#  'Optimal soil fertility',
#  'Absolute soil fertility',
#  'Optimal soil aluminium toxicity',
#  'Absolute soil aluminium toxicity',
#  'Optimal soil salinity',
#  'Absolute soil salinity',
#  'Optimal soil drainage',
#  'Absolute soil drainage',
#  'Killing temperature during rest',
#  'Killing temperature early growth',
#  'Photoperiod',
#  'Climate zone',
#  'Abiotic tolerance',
#  'Abiotic susceptibility',
#  'Introduction risk',
#  'Production system',
#  'Minimum crop cycle',
#  'Maximum crop cycle']
