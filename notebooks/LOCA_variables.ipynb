# %%
import pandas as pd
import geopandas as gpd

# %%
loca_variables_raw = pd.read_csv('../data/climate/NCA4_LOCA/LOCA_variables.csv')

# %%
loca_variables_raw
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0   Cooling Degree Days: Cooling degree days (annu...         NaN         NaN
# 1   Consecutive Dry Days: Annual maximum number of...         NaN         NaN
# 2   Consecutive Dry Days Jan Jul Aug: Summer maxim...         NaN         NaN
# 3   Consecutive Wet Days: Annual maximum number of...         NaN         NaN
# 4   First Freeze Day: Date of the first fall freez...         NaN         NaN
# 5   Growing Degree Days: Growing degree days, base...         NaN         NaN
# 6   Growing Degree Days Modified: Modified growing...         NaN         NaN
# 7   growing-season: Length of the growing (frost-f...         NaN         NaN
# 8   Growing Season 28F: Length of the growing seas...         NaN         NaN
# 9   Growing Season 41F: Length of the growing seas...         NaN         NaN
# 10  Heating Degree Days: Heating degree days (annu...         NaN         NaN
# ...

# %%
loca_variables = pd.DataFrame()
loca_variables['VariableDescription'] = loca_variables_raw['Unnamed: 0']
loca_variables
# Out:
#                                   VariableDescription
# 0   Cooling Degree Days: Cooling degree days (annu...
# 1   Consecutive Dry Days: Annual maximum number of...
# 2   Consecutive Dry Days Jan Jul Aug: Summer maxim...
# 3   Consecutive Wet Days: Annual maximum number of...
# 4   First Freeze Day: Date of the first fall freez...
# 5   Growing Degree Days: Growing degree days, base...
# 6   Growing Degree Days Modified: Modified growing...
# 7   growing-season: Length of the growing (frost-f...
# 8   Growing Season 28F: Length of the growing seas...
# 9   Growing Season 41F: Length of the growing seas...
# 10  Heating Degree Days: Heating degree days (annu...
# 11  Last Freeze Day: Date of the last spring freez...
# 12  Precip Above 99th pctl: Annual total precipita...
# 13  Precip Annual Total: Annual total precipitatio...
# 14  Precip Days Above 99th pctl: Annual number of ...
# 15  Precip 1in: Annual number of days with total p...
# ...

# %%
loca_variables[['Variable', 'Description']] = loca_variables['VariableDescription'].str.split(':', expand=True)
loca_variables.drop(columns=['VariableDescription'], inplace=True)
loca_variables
# Out:
#                             Variable  \
# 0                Cooling Degree Days
# 1               Consecutive Dry Days
# 2   Consecutive Dry Days Jan Jul Aug
# 3               Consecutive Wet Days
# 4                   First Freeze Day
# 5                Growing Degree Days
# 6       Growing Degree Days Modified
# 7                     growing-season
# 8                 Growing Season 28F
# 9                 Growing Season 41F
# 10               Heating Degree Days
# 11                   Last Freeze Day
# 12            Precip Above 99th pctl
# 13               Precip Annual Total
# 14       Precip Days Above 99th pctl
# 15                        Precip 1in
# 16                        Precip 2in
# 17                        Precip 3in
# 18                        Precip 4in
# 19                  Precip Max 1 Day
# 20                  Precip Max 5 Day
# 21             Daily Avg Temperature
# 22             Daily Max Temperature
# 23     Temp Max Days Above 99th pctl
# ...

# %%
loca_variables.to_csv('../data/climate/LOCA_variables_clean.csv')
